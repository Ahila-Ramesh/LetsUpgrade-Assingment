# %% [markdown]
# #Assignment 1 (a)

# %%
lst=[2,4,6,1,5,0,0.1,0.5,7,0.2,0.2,3]

# %%
lst.append(8)

# %%
lst
# Out:
# [2, 4, 6, 1, 5, 0, 0.1, 0.5, 7, 0.2, 0.2, 3, 8]

# %%
lst.index(0.1)
# Out:
# 6

# %%
lst.pop(5)
# Out:
# 0

# %%
lst
# Out:
# [2, 4, 6, 1, 5, 0.1, 0.5, 7, 0.2, 0.2, 3, 8]

# %%
lst.reverse()

# %%
lst
# Out:
# [8, 3, 0.2, 0.2, 7, 0.5, 0.1, 5, 1, 6, 4, 2]

# %%
lst.clear()

# %%
lst
# Out:
# []

# %% [markdown]
# #Assingment 1 (b)

# %%
dit={"a":21,"b":31,"c":41,"d":51}

# %%
dit.get("c")
# Out:
# 41

# %%
dit.copy()
# Out:
# {'a': 21, 'b': 31, 'c': 41, 'd': 51}

# %%
dit.items()
# Out:
# dict_items([('a', 21), ('b', 31), ('c', 41), ('d', 51)])

# %%
dit.values()
# Out:
# dict_values([21, 31, 41, 51])

# %%
dit.pop('d')
# Out:
# 51

# %%
dit
# Out:
# {'a': 21, 'b': 31, 'c': 41}
